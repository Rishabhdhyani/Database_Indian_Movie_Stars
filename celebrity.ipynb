# %%
from requests import get
url = 'https://www.imdb.com/search/name/?birth_place=India&adult=include&count=100&start=1&ref_=rlm'
response = get(url)
print(response.text[:500])
# Out:
# <!DOCTYPE html>
# <html
#     xmlns:og="http://ogp.me/ns#"
#     xmlns:fb="http://www.facebook.com/2008/fbml">
#     <head>
#
#         <meta charset="utf-8">
#         <meta http-equiv="X-UA-Compatible" content="IE=edge">
#
#     <meta name="apple-itunes-app" content="app-id=342792525, app-argument=imdb:///?src=mdot">
#
#
#
#         <script type="text/javascript">var IMDbTimer={starttime: new Date().getTime(),pt:'java'};</script>
#
# <script>
#     if (typeof uet == 'function') {
#       uet("bb", "LoadTitle",

# %%
from bs4 import BeautifulSoup
html_soup = BeautifulSoup(response.text, 'html.parser')
type(html_soup)
# Out:
# bs4.BeautifulSoup

# %%
stars_containers = html_soup.find_all('div', class_ = 'lister-item mode-detail')
print(type(movie_containers))
print(len(movie_containers))
# Out:
# <class 'bs4.element.ResultSet'>
# 100

# %%
first_star=stars_containers[0]

# %%
first_star.h3.a.text
# Out:
# ' Freida Pinto\n'

# %%
first_name = first_star.h3.a.text.strip()
#first_name=first_name.strip()
first_name
# Out:
# 'Freida Pinto'

# %%
first_well_known_movie=first_star.p.a.text.strip()
first_well_known_movie
# Out:
# 'Slumdog Millionaire'

# %%
first_category=first_star.p.text.split('|')[0].strip()
first_category
# Out:
# 'Actress'

# %%
first_bio=first_star.text.split(first_well_known_movie)[1].strip()
first_bios=list(first_bio.split("."))[0]
first_bios
# Out:
# 'Freida Selena Pinto was born in Bombay (now Mumbai), Maharashtra, India, to Sylvia, a school principal, and Frederick Pinto, a senior bank branch manager'

# %%
#first_biot=first_bios[0]
first_bios
# Out:
# 'Freida Selena Pinto was born in Bombay (now Mumbai), Maharashtra, India, to Sylvia, a school principal, and Frederick Pinto, a senior bank branch manager'

# %%
first_image=first_star.find('img')['src']
#first_image=first_image['src']
first_image
# Out:
# 'https://m.media-amazon.com/images/M/MV5BMTg5NDI0MzM0NF5BMl5BanBnXkFtZTcwOTQ4NTIwNw@@._V1_UX140_CR0,0,140,209_AL_.jpg'

# %%
names=[]
category=[]
images=[]
well_known_movie=[]
bio=[]

stars_containers = html_soup.find_all('div', class_ = 'lister-item mode-detail')

for container in stars_containers:
    
    #Name of celebrity
    name = container.h3.a.text.strip()
    names.append(name)
    
    #Image of celebrity
    image=container.find('img')['src']
    images.append(image)
    
    #Category of celebrirty
    categ=container.p.text.split('|')[0].strip()
    category.append(categ)
    
    #Well known movie of celebrity
    well=container.p.a.text.strip()
    well_known_movie.append(well)
    
    #bio of celebrity
    bioa=container.text.split(well)[1].strip()
    biot=list(bioa.split("."))[0]
    bio.append(biot)

# %%
import pandas as pd
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              100 non-null    object
#  1   Category          100 non-null    object
#  2   Image             100 non-null    object
#  3   Well_Known_Movie  100 non-null    object
#  4   Bio               100 non-null    object
# dtypes: object(5)
# memory usage: 4.0+ KB
# None
#                     Name  Category  \
# 0   Freida Pinto          Actress
# 1   Julie Christie        Actress
# 2   Priyanka Chopra       Actress
# 3   M. Night Shyamalan    Producer
# 4   Karen David           Actress
# ..          ...               ...
# 95  Adah Sharma           Actress
# 96  Prithviraj Sukumaran  Actor
# 97  Madhavan              Actor
# 98  N.T. Rama Rao Jr.     Actor
# 99  Zaira Wasim           Actress
#
#                                                                                                                                                            Image  \
# 0   https://m.media-amazon.com/images/M/MV5BMTg5NDI0MzM0NF5BMl5BanBnXkFtZTcwOTQ4NTIwNw@@._V1_UX140_CR0,0,140,209_AL_.jpg
# 1   https://m.media-amazon.com/images/M/MV5BMTY4MzIzMTE5MV5BMl5BanBnXkFtZTcwNDc3NDA2MQ@@._V1_UX140_CR0,0,140,209_AL_.jpg
# 2   https://m.media-amazon.com/images/M/MV5BMjAxNzUwNjExOV5BMl5BanBnXkFtZTcwNDUyMTUxNw@@._V1_UY209_CR70,0,140,209_AL_.jpg
# 3   https://m.media-amazon.com/images/M/MV5BMTczMTA5OTMxMl5BMl5BanBnXkFtZTcwMDA4NDg1Mw@@._V1_UY209_CR87,0,140,209_AL_.jpg
# 4   https://m.media-amazon.com/images/M/MV5BMDZkYjc3YzQtYTExNi00Njc1LTllNGQtMzk2ZGViNWZhNGNkXkEyXkFqcGdeQXVyNDg2NzE1Mg@@._V1_UX140_CR0,0,140,209_AL_.jpg
# ..                                                                                                                                                   ...
# 95  https://m.media-amazon.com/images/M/MV5BYzg0YWFiZmEtOGU1Zi00OWNmLTg5OWQtNmVhMmNkMmNmODZhXkEyXkFqcGdeQXVyNDUzOTQ5MjY@._V1_UX140_CR0,0,140,209_AL_.jpg
# 96  https://m.media-amazon.com/images/M/MV5BZjJlOTJmYjQtOTY3NC00OWVlLTg4MjEtYmRmYWZhZDM4MDRlL2ltYWdlXkEyXkFqcGdeQXVyMjkxNzQ1NDI@._V1_UY209_CR0,0,140,209_AL_.jpg
# 97  https://m.media-amazon.com/images/M/MV5BZjQ4NWIwYzYtOTYwZC00ZDI4LWFmYWEtZjhmNTE3ODVhYzJkXkEyXkFqcGdeQXVyOTc1MzM5MA@@._V1_UY209_CR8,0,140,209_AL_.jpg
# 98  https://m.media-amazon.com/images/M/MV5BMjI0NDQ2MTMzMF5BMl5BanBnXkFtZTgwMzc4MDA3NzE@._V1_UY209_CR5,0,140,209_AL_.jpg
# 99  https://m.media-amazon.com/images/M/MV5BNzU1NjVhYjAtZjYyNC00MDNiLTgyNmUtZGE3NDQ0MWU4MmJhXkEyXkFqcGdeQXVyNDAzNDk0MTQ@._V1_UY209_CR4,0,140,209_AL_.jpg
#
#        Well_Known_Movie  \
# 0   Slumdog Millionaire
# 1   Doctor Zhivago
# 2   Baywatch
# 3   Lady in the Water
# 4   Galavant
# ..       ...
# 95  1920
# 96  Ennu Ninte Moideen
# 97  Vikram Vedha
# 98  Nannaku Prematho
# 99  Dangal
#
#                                                                                                                                                                                                                       Bio
# 0   Freida Selena Pinto was born in Bombay (now Mumbai), Maharashtra, India, to Sylvia, a school principal, and Frederick Pinto, a senior bank branch manager
# 1   Julie Christie, the British movie legend whom Al Pacino called "the most poetic of all actresses," was born in Chabua, Assam, India, on April 14, 1940, the daughter of Rosemary (Ramsden), a painter, and Francis St
# 2   Priyanka Chopra Jonas (née Chopra) was born on July 18, 1982 in Jamshedpur, India, to the family of Capt
# 3   Born in Puducherry, India, and raised in the posh suburban Penn Valley area of Philadelphia, Pennsylvania, M
# 4   From India to Canada, England to America, Karen David has crisscrossed the world making true fans everywhere along the way
# ..                                                                                                                         ...
# 95  Adah Sharma (May 11, 1992) is a Bollywood actress
# 96  Prithviraj Sukumaran (born 16 October 1982), credited mononymously as Prithviraj, is an Indian actor, playback singer and producer best known for his work in Malayalam films
# 97  Madhavan was born on June 1, 1970, in a Tamil-speaking family
# 98  N
# 99  Zaira Wasim was born on October 23, 2000 in Srinagar, Jammu and Kashmir, India
#
# [100 rows x 5 columns]

# %% [markdown]
# 1

# %%
import pandas as pd
from IPython.core.display import HTML

# convert your links to html tags 
def path_to_image_html(path):
    return '<img src="'+ path + '" width="60" >'

pd.set_option('display.max_colwidth', -1)

HTML(testf_df.to_html(escape=False ,formatters=dict(Image=path_to_image_html)))
# Out:
# /home/rd/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Name</th>
#       <th>Category</th>
#       <th>Image</th>
#       <th>Well_Known_Movie</th>
#       <th>Bio</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Freida Pinto</td>
#       <td>Actress</td>
#       <td><img src="https://m.media-amazon.com/images/M/MV5BMTg5NDI0MzM0NF5BMl5BanBnXkFtZTcwOTQ4NTIwNw@@._V1_UX140_CR0,0,140,209_AL_.jpg" width="60" ></td>
#       <td>Slumdog Millionaire</td>
#       <td>Freida Selena Pinto was born in Bombay (now Mumbai), Maharashtra, India, to Sylvia, a school principal, and Frederick Pinto, a senior bank branch manager</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>
td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>Hrithik Roshan</td>
#       <td>Actor</td>
#       <td><img src="https://m.media-amazon.com/images/M/MV5BZjYwYjE4YjQtMTFmMi00NTlhLThjZjUtZTIyMTczMGU2ZDE5XkEyXkFqcGdeQXVyNzM2NzM0NDU@._V1_UX140_CR0,0,140,209_AL_.jpg" width="60" ></td>
#       <td>Super 30</td>
#       <td>Hrithik Roshan is an Indian actor, born on 10th January 1974, well known globally for his versatile roles, unmatchable dancing skills and attractive looks</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>Salman Khan</td>
#       <td>Actor</td>
#       <td><img src="https://m.media-amazon.com/images/M/MV5BMjMwNTIxODg0OF5BMl5BanBnXkFtZTgwODg2NzM0OTE@._V1_UY209_CR7,0,140,209_AL_.jpg" width="60" ></td>
#       <td>Sultan</td>
#       <td>Born on December 27, 1965 Salman Khan is the son of the legendary writer Salim Khan, who penned many super-hits in the yesteryear's like Sholay (1975), Deewaar (1975), and Don (1978)</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>Akshay Kumar</td>
#       <td>Actor</td>
#       <td><img src="https://m.media-amazon.com/images/M/MV5BODI4NDY1NzkyM15BMl5BanBnXkFtZTgwNzM3MDM0OTE@._V1_UY209_CR13,0,140,209_AL_.jpg" width="60" ></td>
#       <td>Hera Pheri</td>
#       <td>Akshay Kumar, born September 9, 1967, is an actor</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>Amitabh Bachchan</td>
#       <td>Actor</td>
#       <td><img src="https://m.media-amazon.com/images/M/MV5BNTk1OTUxMzIzMV5BMl5BanBnXkFtZTcwMzMxMjI0Nw@@._V1_UY209_CR6,0,140,209_AL_.jpg" width="60" ></td>
#       <td>Black</td>
#       <td>Son of well known poet Harivansh Rai Bachchan and Teji Bachchan</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>Irrfan Khan</td>
#       <td>Actor</td>
#       <td><img src="https://m.media-amazon.com/images/M/MV5BNDg3NDgxNzY4NF5BMl5BanBnXkFtZTcwODMxODQzMg@@._V1_UY209_CR8,0,140,209_AL_.jpg" width="60" ></td>
#       <td>Dabba</td>
#       <td>Born Sahabzade Irfan Ali Khan, in Jaipur, Rajasthan (NW India) January 7, 1967 to a Pashto speaking Muslim family</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>Rani Mukerji</td>
#       <td>Actress</td>
#       <td><img src="https://m.media-amazon.com/images/M/MV5BMjI4MjI2MTEwOV5BMl5BanBnXkFtZTgwMzkxMDU0OTE@

# %%
#Now we will be scrapping multiple pages

# %%
pages = [str(i) for i in range(1,4766,100)]

# %%
from time import sleep
from random import randint

# %%
from time import time
start_time = time()
requests = 0
for _ in range(5):
# A request would go here
    requests += 1
    sleep(randint(1,3))
    elapsed_time = time() - start_time
    print('Request: {}; Frequency: {} requests/s'.format(requests, requests/elapsed_time))
# Out:
# Request: 1; Frequency: 0.9988385830475038 requests/s
# Request: 2; Frequency: 0.998745943186333 requests/s
# Request: 3; Frequency: 0.7491073962474832 requests/s
# Request: 4; Frequency: 0.7990509623827443 requests/s
# Request: 5; Frequency: 0.713443436745083 requests/s

# %%
from IPython.core.display import clear_output
start_time = time()
requests = 0
for _ in range(5):
# A request would go here
    requests += 1
    sleep(randint(1,3))
    current_time = time()
    elapsed_time = current_time - start_time
    print('Request: {}; Frequency: {} requests/s'.format(requests, requests/elapsed_time))
clear_output(wait = True)
# Out:
# Request: 1; Frequency: 0.9988775944465097 requests/s
# Request: 2; Frequency: 0.665731419380475 requests/s
# Request: 3; Frequency: 0.499375865098439 requests/s
# Request: 4; Frequency: 0.570712016069944 requests/s
# Request: 5; Frequency: 0.4993880142228352 requests/s

# %%
from warnings import warn
warn("Warning Simulation")
# Out:
# /home/rd/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Warning Simulation

# %%
names=[]
category=[]
images=[]
well_known_movie=[]
bio=[]

start_time = time()
requests = 0

for page in pages:
    
    response = get('https://www.imdb.com/search/name/?birth_place=India&adult=include&count=100&start=' + page + 
    '&ref_=rlm')
    
    # Pause the loop
    sleep(randint(8,15))

    # Monitor the requests
    requests += 1
    elapsed_time = time() - start_time
    print('Request:{}; Frequency: {} requests/s'.format(requests, requests/elapsed_time))
    clear_output(wait = True)

    # Throw a warning for non-200 status codes
    if response.status_code != 200:
        warn('Request: {}; Status code: {}'.format(requests, response.status_code))

    # Break the loop if the number of requests is greater than expected
    if requests > 72:
        warn('Number of requests was greater than expected.')
        break
        
    # Parse the content of the request with BeautifulSoup
    page_html = BeautifulSoup(response.text, 'html.parser') 
    
    stars_containers = page_html.find_all('div', class_ = 'lister-item mode-detail')
    
    for container in stars_containers:
        
        if container.find('span', class_='ghost') is not None:
        
            #Name of celebrity
            name = container.h3.a.text.strip()
            names.append(name)

            #Image of celebrity
            image=container.find('img')['src']
            images.append(image)

            #Category of celebrirty
            categ=container.p.text.split('|')[0].strip()
            category.append(categ)

            #Well known movie of celebrity
            well=container.p.a.text.strip()
            well_known_movie.append(well)

            #bio of celebrity
            bioa=container.text.split(well)[1].strip()
            biot=list(bioa.split("."))[0]
            bio.append(biot)
# Out:
# Request:48; Frequency: 0.05989491804509071 requests/s

# %%
Celebrity_info = pd.DataFrame({'Name': names,
'Category': category,
'Image': images,
'Well_Known_Movie': well_known_movie,
'Bio': bio
})
print(Celebrity_info.info())
Celebrity_info.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4557 entries, 0 to 4556
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              4557 non-null   object
#  1   Category          4557 non-null   object
#  2   Image             4557 non-null   object
#  3   Well_Known_Movie  4557 non-null   object
#  4   Bio               4557 non-null   object
# dtypes: object(5)
# memory usage: 178.1+ KB
# None
#                      Name  Category  \
# 0  Freida Pinto            Actress
# 1  Julie Christie          Actress
# 2  Priyanka Chopra         Actress
# 3  M. Night Shyamalan      Producer
# 4  Karen David             Actress
# 5  Erick Avari             Actor
# 6  Shah Rukh Khan          Actor
# 7  Mark Heap               Actor
# 8  Aamir Khan              Actor
# 9  Aishwarya Rai Bachchan  Actress
#
#                                                                                                                                                   Image  \
# 0  https://m.media-amazon.com/images/M/MV5BMTg5NDI0MzM0NF5BMl5BanBnXkFtZTcwOTQ4NTIwNw@@._V1_UX140_CR0,0,140,209_AL_.jpg
# 1  https://m.media-amazon.com/images/M/MV5BMTY4MzIzMTE5MV5BMl5BanBnXkFtZTcwNDc3NDA2MQ@@._V1_UX140_CR0,0,140,209_AL_.jpg
# 2  https://m.media-amazon.com/images/M/MV5BMjAxNzUwNjExOV5BMl5BanBnXkFtZTcwNDUyMTUxNw@@._V1_UY209_CR70,0,140,209_AL_.jpg
# 3  https://m.media-amazon.com/images/M/MV5BMTczMTA5OTMxMl5BMl5BanBnXkFtZTcwMDA4NDg1Mw@@._V1_UY209_CR87,0,140,209_AL_.jpg
# 4  https://m.media-amazon.com/images/M/MV5BMDZkYjc3YzQtYTExNi00Njc1LTllNGQtMzk2ZGViNWZhNGNkXkEyXkFqcGdeQXVyNDg2NzE1Mg@@._V1_UX140_CR0,0,140,209_AL_.jpg
# 5  https://m.media-amazon.com/images/M/MV5BNzk3OTE3NTg3N15BMl5BanBnXkFtZTYwMDc1ODAz._V1_UY209_CR3,0,140,209_AL_.jpg
# 6  https://m.media-amazon.com/images/M/MV5BZDk1ZmU0NGYtMzQ2Yi00N2NjLTkyNWEtZWE2NTU4NTJiZGUzXkEyXkFqcGdeQXVyMTExNDQ2MTI@._V1_UY209_CR3,0,140,209_AL_.jpg
# 7  https://m.media-amazon.com/images/M/MV5BMTgyMzE4MjQ1OV5BMl5BanBnXkFtZTcwMzcxMTUwOA@@._V1_UY209_CR34,0,140,209_AL_.jpg
# 8  https://m.media-amazon.com/images/M/MV5BMjAwMjk3NDUzN15BMl5BanBnXkFtZTcwNjI4MTY0NA@@._V1_UX140_CR0,0,140,209_AL_.jpg
# 9  https://m.media-amazon.com/images/M/MV5BMjEyMjEyODkzN15BMl5BanBnXkFtZTcwODkxMTY1Mg@@._V1_UX140_CR0,0,140,209_AL_.jpg
#
#       Well_Known_Movie  \
# 0  Slumdog Millionaire
# 1  Doctor Zhivago
# 2  Baywatch
# 3  Lady in the Water
# 4  Galavant
# 5  Mr. Deeds
# 6  Don 2
# 7  Stardust
# 8  Taare Zameen Par
# 9  Jodhaa Akbar
#
#                                                                                                                                                                                                                      Bio
# 0  Freida Selena Pinto was born in Bombay (now Mumbai), Maharashtra, India, to Sylvia, a school principal, and Frederick Pinto, a senior bank branch manager
# 1  Julie Christie, the British movie legend whom Al Pacino called "the most poetic of all actresses," was born in Chabua, Assam, India, on April 14, 1940, the daughter of Rosemary (Ramsden), a painter, and Francis St
# 2  Priyanka Chopra Jonas (née Chopra) was born on July 18, 1982 in Jamshedpur, India, to the family of Capt
# 3  Born in Puducherry, India, and raised in the posh suburban Penn Valley area of Philadelphia, Pennsylvania, M
# 4  From India to Canada, England to America, Karen David has crisscrossed the world making true fans everywhere along the way
# 5  Erick Avari was born on April 13, 1952 in Darjeeling, India
# 6  Shahrukh Khan was born on 2 November 1965 in New Delhi, India
# 7  Mark Heap was born on May 13, 1957 in Kodaikanal, Tamil Nadu, India
# 8  Aamir is no doubt one of the most dedicated actors in this world
# 9  Born into a traditional south Indian family, Aishwarya started modeling at a young age

# %%
Celebrity_info
# Out:
#                         Name          Category  \
# 0     Freida Pinto            Actress
# 1     Julie Christie          Actress
# 2     Priyanka Chopra         Actress
# 3     M. Night Shyamalan      Producer
# 4     Karen David             Actress
# ...           ...                 ...
# 4552  Kirti Premraj Jain      Producer
# 4553  Jyotirindranath Tagore  Music Department
# 4554  Dwijendralal Roy        Writer
# 4555  Raveendranath           Director
# 4556  Inderjit Hassanpuri     Writer
#
#                                                                                                                                                      Image  \
# 0     https://m.media-amazon.com/images/M/MV5BMTg5NDI0MzM0NF5BMl5BanBnXkFtZTcwOTQ4NTIwNw@@._V1_UX140_CR0,0,140,209_AL_.jpg
# 1     https://m.media-amazon.com/images/M/MV5BMTY4MzIzMTE5MV5BMl5BanBnXkFtZTcwNDc3NDA2MQ@@._V1_UX140_CR0,0,140,209_AL_.jpg
# 2     https://m.media-amazon.com/images/M/MV5BMjAxNzUwNjExOV5BMl5BanBnXkFtZTcwNDUyMTUxNw@@._V1_UY209_CR70,0,140,209_AL_.jpg
# 3     https://m.media-amazon.com/images/M/MV5BMTczMTA5OTMxMl5BMl5BanBnXkFtZTcwMDA4NDg1Mw@@._V1_UY209_CR87,0,140,209_AL_.jpg
# 4     https://m.media-amazon.com/images/M/MV5BMDZkYjc3YzQtYTExNi00Njc1LTllNGQtMzk2ZGViNWZhNGNkXkEyXkFqcGdeQXVyNDg2NzE1Mg@@._V1_UX140_CR0,0,140,209_AL_.jpg
# ...                                                                                                                                                    ...
# 4552  https://m.media-amazon.com/images/G/01/imdb/images/nopicture/medium/name-2135195744._CB466677935_.png
# 4553  https://m.media-amazon.com/images/G/01/imdb/images/nopicture/medium/name-2135195744._CB466677935_.png
# 4554  https://m.media-amazon.com/images/G/01/imdb/images/nopicture/medium/name-2135195744._CB466677935_.png
# 4555  https://m.media-amazon.com/images/G/01/imdb/images/nopicture/medium/name-2135195744._CB466677935_.png
# 4556  https://m.media-amazon.com/images/G/01/imdb/images/nopicture/medium/name-2135195744._CB466677935_.png
#
#          Well_Known_Movie  \
# 0     Slumdog Millionaire
# 1     Doctor Zhivago
# 2     Baywatch
# 3     Lady in the Water
# 4     Galavant
# ...        ...
# 4552  Romance Complicated
# 4553  Charulata
# 4554  Mathru Bhoomi
# 4555  Veerappan
# 4556  Man Jeete Jag Jeet
#
#                                                                                                                                                                                                                         Bio
# 0     Freida Selena Pinto was born in Bombay (now Mumbai), Maharashtra, India, to Sylvia, a school principal, and Frederick Pinto, a senior bank branch manager
# 1     Julie Christie, the British movie legend whom Al Pacino called "the most poetic of all actresses," was born in Chabua, Assam, India, on April 14, 1940, the daughter of Rosemary (Ramsden), a painter, and Francis St
# 2     Priyanka Chopra Jonas (née Chopra) was born on July 18, 1982 in Jamshedpur, India, to the family of Capt
# 3     Born in Puducherry, India, and raised in the posh suburban Penn Valley area of Philadelphia, Pennsylvania, M
# 4     From India to Canada, England to America, Karen David has crisscrossed the world making true fans everywhere along the way
# ...                                                                                                                          ...
# 4552
# 4553
# 4554  Father of Late Dilip Kumar Roy
# 4555
# 4556
#
# [4557 rows x 5 columns]

# %%
import pandas as pd
from IPython.core.display import HTML

# convert your links to html tags 
def path_to_image_html(path):
    return '<img src="'+ path + '" width="60" >'

pd.set_option('display.max_colwidth', -1)

HTML(Celebrity_info.to_html(escape=False ,formatters=dict(Image=path_to_image_html)))
# Out:
# /home/rd/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Name</th>
#       <th>Category</th>
#       <th>Image</th>
#       <th>Well_Known_Movie</th>
#       <th>Bio</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Freida Pinto</td>
#       <td>Actress</td>
#       <td><img src="https://m.media-amazon.com/images/M/MV5BMTg5NDI0MzM0NF5BMl5BanBnXkFtZTcwOTQ4NTIwNw@@._V1_UX140_CR0,0,140,209_AL_.jpg" width="60" ></td>
#       <td>Slumdog Millionaire</td>
#       <td>Freida Selena Pinto was born in Bombay (now Mumbai), Maharashtra, India, to Sylvia, a school principal, and Frederick Pinto, a senior bank branch manager</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Julie Christie</td>
#       <td>Actress</td>
#       <td><img src="https://m.media-amazon.com/images/M/MV5BMTY4MzIzMTE5MV5BMl5BanBnXkFtZTcwNDc3NDA2MQ@@._V1_UX140_CR0,0,140,209_AL_.jpg" width="60" ></td>
#       <td>Doctor Zhivago</td>
#       <td>Julie Christie, the British movie legend whom Al Pacino called "the most poetic of all actresses," was born in Chabua, Assam, India, on April 14, 1940, the daughter of Rosemary (Ramsden), a painter, and Francis St</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Priyanka Chopra</td>
#       <td>Actress</td>
#       <td><img src="https://m.media-amazon.com/images/M/MV5BMjAxNzUwNjExOV5BMl5BanBnXkFtZTcwNDUyMTUxNw@@._V1_UY209_CR70,0,140,209_AL_.jpg" width="60" ></td>
#       <td>Baywatch</td>
#       <td>Priyanka Chopra Jonas (née Chopra) was born on July 18, 1982 in Jamshedpur, India, to the family of Capt</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>M. Night Shyamalan</td>
#       <td>Producer</td>
#       <td><img src="https://m.media-amazon.com/images/M/MV5BMTczMTA5OTMxMl5BMl5BanBnXkFtZTcwMDA4NDg1Mw@@._V1_UY209_CR87,0,140,209_AL_.jpg" width="60" ></td>
#       <td>Lady in the Water</td>
#       <td>Born in Puducherry, India, and raised in the posh suburban Penn Valley area of Philadelphia, Pennsylvania, M</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Karen David</td>
#       <td>Actress</td>
#       <td><img src="https://m.media-amazon.com/images/M/MV5BMDZkYjc3YzQtYTExNi00Njc1LTllNGQtMzk2ZGViNWZhNGNkXkEyXkFqcGdeQXVyNDg2NzE1Mg@@._V1_UX140_CR0,0,140,209_AL_.jpg" width="60" ></td>
#       <td>Galavant</td>
#       <td>From India to Canada, England to America, Karen David has crisscrossed the world making true fans everywhere along the way</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Erick Avari</td>
#       <td>Actor</td>
#       <td><img src="https://m.media-amazon.com/images/M/MV5BNzk3OTE3NTg3N15BMl5BanBnXkFtZTYwMDc1ODAz._V1_UY209_CR3,0,140,209_AL_.jpg" width="60" ></td>
#       <td>Mr. Deeds</td>
#       <td>Erick Avari was born on April 13, 1952 in Darjeeling, India</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Shah Rukh Khan</td>
#       <td>Actor</td>
#       <td><img src="https://m.media-amazon.com/images/M/MV5BZDk1ZmU0NGYtMzQ2Yi00N2NjLTkyNWEtZWE2NTU4NTJiZGUzXkEyXkFqcGdeQXVyMTExNDQ2MTI@._V1_UY209_CR3,0,140,209_AL_.jpg" width="60" ></td>
#       <td>Don 2</td>
#       <td>Shahrukh Khan was born on 2 November 1965 in New Delhi, India</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Mark Heap</td>
#       <td>Actor</td>
#       <td><img src="https://m.media-amazon.com/images/M/MV5BMTgyMzE4MjQ1OV5BMl5BanBnXkFtZTcwMzcxMTUwOA@@._V1_UY209_CR34,0,140,209_AL_.jpg" width="60" ></td>
#       <td>Stardust</td>
#       <td>Mark Heap was born on May 13, 1957 in Kodaikanal, Tamil Nadu, India</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>